# %% [markdown]
# Logaritimico: a ideia do logaritimo e encontrar o que na base(a), elevado a X(expoente), da o nosso logaritimo(b)<br>
# a: base , deve ser maior q 0 e diferente de  1 <br>
# b: logaritimos <br>
# c: expoente<br><br>
# log<sub>a</sub><sup>b</sup>=c<br>

# %% [markdown]
#
# log<sub>2</sub><sup>8</sup>=x<br>
# $8= 2^x$<br>
# $2^3=2^x$<br>
# $x=3$

# %%
# estudar propriedades e o restantes das coisas

# %% [markdown]
# Funcoes

# %% [markdown]
# f(x) = log<sub>a</sub><sup>b</sup>=c<br>

# %% [markdown]
# crescente: a>1 <br>
# decrescente: entre 0 e 1<br>
# o grafico passa por 1

# %%
import numpy as np
import matplotlib.pyplot as plt 

# funcao exponencial
x =  np.linspace(-5,20,50)
y = 2**x 
plt.plot(x,y)

# %%
import math 
# logaritmica 

x =  np.linspace(-5,20,50)
y2 = np.log(x)
plt.plot(x,y2)
# Out:
# C:\Users\Familia\AppData\Local\Temp\ipykernel_13376\3399260756.py:4: RuntimeWarning: invalid value encountered in log
#   y2 = np.log(x)
